# %% [markdown]
# # M3 Week 1 Evaluation Setup
#
# This notebook tests:
# - regression metrics
# - classification metrics
# - evaluation framework setup

# %%
import sys
import os

sys.path.append("..")

from src.eval.metrics import regression_metrics
from src.eval.metrics import classification_metrics

# %%
y_true = [50, 60, 70, 80]

y_pred = [52, 59, 68, 82]

results = regression_metrics(y_true, y_pred)

print(results)
# Out:
# {'MAE': 1.75, 'RMSE': np.float64(1.8027756377319946), 'R2': 0.974}

# %%
y_true = [1,0,1,1,0]

y_pred = [1,0,1,0,0]

results = classification_metrics(y_true, y_pred)

print(results)
# Out:
# {'accuracy': 0.8, 'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'confusion_matrix': array([[2, 0],
#        [1, 2]])}

# %%
import pandas as pd

data = {
    "actual": [1,0,1,1,0],
    "predicted": [1,1,1,0,0]
}

df = pd.DataFrame(data)
